# %% [markdown]
# <a href="https://colab.research.google.com/github/PeterShiaush/ColabYolo26/blob/main/%E5%AD%B8%E7%BF%92VS_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# #安裝 miniconda 環境，以hello.py測試環境
# ---

# %% [markdown]
# ## 0. 安裝 miniconda
#  1. https：//www.anaconda.com/download/success
#  2. Miniconda
#  3. Graphical Installer​
# ---

# %% [markdown]
# ## 1. 以 Anaconda PowerShell Prompt  建立 yolo26虛擬環境
# 建立 yolo26_env 需要的虛擬環境： Python=3.12， 未來類似專案的共用環境 ，
# 主要核心目的是區分python 版本不同的環境，應用在不同專案
#
#  1. 創造 conda create -n yolo26_env python=3.12 -y
#  2. 檢查是否創造成功 conda env list
#  3. 啟動 conda activate yolo26_env
#  4. 檢查是否啟動成功 conda env list

# %% [markdown]
# **以下僅參考**
#
# 如果急需使用，以conda直接關閉 SSL 憑證驗證。這是最快的方法，但請注意這會降低連線安全性。
# 在終端機執行此指令：
# conda config --set ssl_verify false
# 改回安全
# conda config --set ssl_verify true
# 檢查是否 ssl_verify true
# conda config --show ssl_verify
#
# **以下僅參考**
#
# Python 環境管理：venv、conda 與 hatch 的選擇

# %% [markdown]
# ---
#
# ## 2A. VS Code 創建專案資料夾：yolo01
#
#
#  1.  資料夾管理，建立資料夾：  yolo01
#  2.  將yolo01專案資料夾，拖曳入桌面 VS Code
#  3.  或 開啟VS Code 選 File > Open Folder，資料夾：  yolo01

# %% [markdown]
# ## 2B. yolo01，連接虛擬環境 yolo26_env
#
#  連接到剛剛建立的 yolo26_env 虛擬環境的關鍵步驟。
#
#  左下角輪圈設定，找到 Command Palette
#
#  或 Ctrl + Shift + P ， 選擇 Python： Select Interpreter 後，
#
#  請執行以下操作：
#  1. 尋找路徑：在彈出的清單中，尋找名稱包含 yolo26_env 的選項。 它通常會顯示為：Python 3.12.x ('yolo26_env'： conda)
#  2. 選取它：點擊該選項。

# %% [markdown]
#  **以下僅參考**
#
#  Visual Studio Code    VS Code 將此功能發揚光大，幾乎所有編輯器功能與延伸模組（Extensions）都定義在此面板中。
#  快捷鍵：Ctrl + Shift + P (Windows / Linux) 或 Cmd + Shift + P (macOS)

# %% [markdown]
# ---
#
# ## 3. 啟動 VS Code 的power shell 終端機
#  1. Ctrl+ Shift + ` （鍵盤左上角，數字 1 左邊的 ~ 波浪號鍵） 或 上面選單 Terminal 選取 New Terminal 點擊該選項。
#  2. 常用終端機快捷鍵切換顯示/隱藏終端機：Ctrl + ` （鍵盤左上角，數字 1 左邊的 ~ 波浪號鍵）
#  3. 確認啟動 conda，連接 yolo26_env 環境

# %% [markdown]
# **以下僅參考**
#
# 如果沒有啟動 conda，連接 yolo26_env 環境
#  1. C：\Users\USER\miniconda3\Scripts\activate    ， Conda 主啟動腳本路徑。目的是讓電腦終端機，「認識」conda 這個指令
#  2. conda activate yolo26_env
#
# **以下僅參考**
#
# 如果沒有啟動 conda， VS Code 終端機（Terminal）顯示紅字且無法進入 Miniconda 環境，
#
# 最常見原因：PowerShell 權限限制 也就是PowerShell 的執行策略限制，如果你看到類似 ...running scripts is disabled on this system... 的紅字，
# 這是因為 PowerShell 限制了腳本執行。
#
# 解決方法：
#  1. win 按右鍵，選終端機(系統管理員) ，系統管理身分開啟 PowerShell。
#  2. 輸入以下命令並按 Enter： set-executionpolicy remotesigned
#  3. 輸入 y 並確認。
#  4. 重啟 VS Code。

# %% [markdown]
# ---
#
# ## 4. 確認 VS Code 的python環境
#  1. new file： hello.py
#  2. print("Hello, World! Welcome to Python programming.")
#  3. 執行，終端機出現 Hello, World! Welcome to Python programming.
#  4. 確認啟動 conda，連接 yolo26_env 環境
#  5. 確認狀態欄：選取後，VS Code 視窗右下角應該會顯示 3.12.x ('yolo26_env')。

# %% [markdown]
# **以下僅參考**
#
# 如果沒有啟動 conda，連接 yolo26_env 環境
#  1. C：\Users\USER\miniconda3\Scripts\activate    ， Conda 主啟動腳本路徑。目的是讓電腦終端機，「認識」conda 這個指令
#  2. conda activate yolo26_env

# %% [markdown]
# ---
#
# # 安裝 yolo26 與 streamlit 測試環境
#
# ---

# %% [markdown]
# ## 1. 下載  完成的訓練模型 best.pt
#  1. 下載 best.pt
#  2. 拖曳 best.pt 進入 VS Code 剛剛創建專案資料夾： yolo01

# %% [markdown]
# ---
# ## 2. 創建新檔案 requirements.txt，
#
# 告訴 streamlit 需要的測試環境，內容如下：
#  1. streamlit
#  2. ultralytics
#  3. opencv-python-headless
#  4. numpy
#  5. pillow

# %% [markdown]
# ---
# ## 3. streamlit_app.py，程式碼內容如下

# %%
import streamlit as st
import cv2
from ultralytics import YOLO
import numpy as np
from PIL import Image

# 1. 頁面基本配置
st.set_page_config(page_title="學生專題：勝利手勢偵測", layout="wide")

# --- 側邊欄 (Sidebar) ---
st.sidebar.header("📁 學生基本資料")
school = st.sidebar.text_input("高中名稱", "某某高級中學")
name = st.sidebar.text_input("學生姓名", "王小明")
interest = st.sidebar.text_area("興趣", "電腦視覺、人工智慧、手勢識別")

st.sidebar.divider()

st.sidebar.header("⚙️ 模型參數設定")
# 置信度滑桿：預設 0.25，範圍 0.0 到 1.0
conf_threshold = st.sidebar.slider(
    "信心程度 (Confidence Score)",
    min_value=0.0,
    max_value=1.0,
    value=0.25,
    step=0.05
)

st.sidebar.info(f"當前過濾：僅顯示置信度 ≥ {conf_threshold} 的結果")

# --- 主畫面 (Main) ---
st.title("✌️ 勝利手勢 (Victory Gesture) 偵測系統")
st.markdown(f"**開發者：** {school} - {name}")

# 2. 載入模型
@st.cache_resource
def load_yolo_model():
    # 確保 best.pt 與此程式碼在同一目錄
    return YOLO("best.pt")

model = load_yolo_model()

# 3. 上傳檔案區塊
uploaded_file = st.file_uploader("上傳照片進行測試", type=["jpg", "jpeg", "png"])

if uploaded_file is not None:
    # 讀取影像
    img_pil = Image.open(uploaded_file)
    img_cv = cv2.cvtColor(np.array(img_pil), cv2.COLOR_RGB2BGR)

    # 4. 執行偵測 (傳入滑桿設定的 conf 值)
    # YOLO 會自動過濾掉低於 conf_threshold 的框
    results = model.predict(source=img_cv, conf=conf_threshold)

    # 5. 繪製並顯示結果
    res_plotted = results[0].plot()
    res_rgb = cv2.cvtColor(res_plotted, cv2.COLOR_BGR2RGB)

    col1, col2 = st.columns(2)

    with col1:
        st.subheader("原始影像")
        st.image(img_pil, use_container_width=True)

    with col2:
        st.subheader("偵測結果")
        st.image(res_rgb, use_container_width=True)

    # 6. 數據統計
    num_boxes = len(results[0].boxes)
    if num_boxes > 0:
        st.success(f"✅ 偵測完成！在信心門檻 {conf_threshold} 下，共偵測到 {num_boxes} 個目標。")

        # 可選：列出每個框的詳細分數
        with st.expander("查看詳細偵測分數"):
            for i, box in enumerate(results[0].boxes):
                score = float(box.conf)
                st.write(f"目標 {i+1}: 信心程度 {score:.2f}")
    else:
        st.warning(f"❌ 在信心門檻 {conf_threshold} 下，未發現任何目標。請嘗試調低滑桿數值。")

else:
    st.info("👋 請在上方上傳照片，並於左側調整模型參數。")

# %% [markdown]
# ---
# ## 4. 安裝 所有 套件
#
# 在VS Code 的power shell 終端機 或 Command Prompt(CMD)終端機
#
#  1. 升級 pip（確保安裝順利）： python -m pip install --upgrade pip
#  2. 一鍵安裝 所有 套件： pip install -r requirements.txt
#  3. 檢查 所有 套件，yolo26_env 環境： conda list

# %% [markdown]
# ---
# ## 5. 確認以上動作完成
#
# 在VS Code 的power shell 終端機 或 Command Prompt(CMD)終端機
#  1. 安裝完成後，直接啟動你的 Streamlit 專案來驗證環境： streamlit run streamlit_app.py
#  2. Ctrl鍵 + C，停止 streamlit 在地環境

# %% [markdown]
# ---
# # 移植到 github 與 streamlit WEB 測試 cloud環境
#
# ---
#
# 好的，最後步驟，請跟著以下結構清晰的步驟，一步一步完成
#
# 上傳 **github**
#
# 與 **streamlit** 雲端部署。

# %% [markdown]
# ---
# ## 🌐 步驟一：獲取 GitHub 儲存庫網址
#
#    1. 打開瀏覽器
#    * 進入您在 GitHub 上，**綠色**的 「**New**」 按鈕，建立好的 V_gesture 儲存庫（Repository）頁面。記得 **public**，以及 **python**
#    2. 複製 HTTPS 網址
#    * 在頁面中找到**綠色**的 「**Code**」 按鈕並點擊它。
#       * 確保分頁停留在 HTTPS。
#       * **非常重要**，點擊網址右側的複製圖示（網址為 https://github.com/?????/V_gesture.git）。

# %% [markdown]
# ---
# ## 💻 步驟二：在 VS Code 中設定 Git，並以終端機，上傳專案
# 回到 VS Code，確定內建終端機（Terminal）的路徑在 yolo01 資料夾下，依序輸入以下指令：
#
#    1. 初始化本地 Git
#
#    * git init
#
#    2. 將所有檔案加入暫存區
#
#    * git add .
#
#    3. 提交檔案並建立紀錄
#
#    * git commit -m "Initial commit with YOLO config"
#
#    4. 不論是否存在，強制將目前分支改名為 main。這能百分之百確保您的本地分支成功切換
#
#    * git branch -M main
#
#    5. 綁定 GitHub 遠端儲存庫（使用固定代號 origin）
#    * 直接複製此行，origin 不用換：
#
#    * git remote add origin https://github.com/?????/V_gesture.git
#      * 注意：如果出現 already exists 錯誤，請改輸入：git remote set-url origin https://github.com/?????/V_gesture.git
#
#
#    6. 強制合併遠端檔案（允許不相關的歷史紀錄）
#    * 請直接複製並執行這行指令，它會把 GitHub 上的 .gitignore和 README 兩個檔案，抓回你的電腦，並允許兩邊融合：
#
#    * git pull origin main --allow-unrelated-histories
#
#      * 注意：執行此指令後，終端機可能會跳出一個黑底畫面（Vim 編輯器）要你輸入 Commit 訊息，如果跳出來，請依序按下鍵盤的　 **:** 　wq ，然後按 Enter 即可退出。
#      * 注意：先按一下鍵盤左上角的 Esc 鍵（確保退出輸入模式）。 再按下鍵盤　 **:**  　，再按下wq ，再按Enter。 wq的意思是 Write 寫入存檔 + Quit 離開)
#
#
#    7. 推送到 GitHub
#    * 直接複製此行，網址已經縮寫成 origin：
#
#    * git push -u origin main
#
#    (如果跳出瀏覽器視窗要求驗證 GitHub 權限，請點擊同意登入。上傳成功後，終端機會顯示 100% 且沒有報錯)

# %% [markdown]
# **以下僅參考 **
#
# 是的，:（冒號）確實是切換模式！
# 在 Vim 編輯器中，按鍵的功能取決於你當前處於什麼「模式」：
#
#    1. 先按 Esc：這是為了確保你退出「編輯模式」（此時無法直接打字修改文章）。
#    2. 接著打 :（冒號）：這會切換到 「底線命令模式」（Command-line mode）。你會看到視窗的最左下角出現了一個冒號 :，這代表 Vim 已經準備好接收你的系統指令。
#    3. 最後打 wq 並按 Enter：在冒號後面接著打 wq，就是下達「存檔（write）並離開（quit）」的命令。
#
# 所以請放心在按完 Esc 後，直接按下 :、w、q，最後敲擊 Enter 鍵，就能順利關閉這個畫面並自動存檔了！
# 離開後，別忘了在終端機輸入 git push -u origin main 完成最後的上傳步驟喔！

# %% [markdown]
# ---
# ## 🚀 步驟三：連接 Streamlit Community Cloud 部署網頁
#
#    1. 登入平台
#    * 打開瀏覽器，進入 Streamlit Community Cloud 官網。
#       * 點擊 Sign in 並選擇 Continue with GitHub 完成登入。
#    2. 建立新 App
#    * 進入後台首頁，點擊右上角的 "**Create app**" 按鈕。
#    3. 填寫專案部署資訊
#    * Repository：選擇或輸入 shiaush/**V_gesture**。
#       * Branch：輸入 main。
#       * Main file path：輸入 **streamlit_app.py**。
#    4. 啟動與測試
#    * 點擊最下方的 "Deploy!" 按鈕。
#       * 右下角會出現系統日誌（Log）開始安裝 requirements.txt 中的套件（約需 3~5 分鐘）。
#       * 當網頁順利顯現，即代表雲端環境測試成功！
#
#
# 請完成步驟二的 git push 後告訴我。 https://vgesture-k9qzatmpjw7aqsvsls9xdh.streamlit.app/
#    1.  不可能打以上串網址，請轉 QR code 。 https://qrcode-generator.tw/
#    2. 轉口試委員模式，委員的手機，手機掃描，瀏覽器開啟，上傳照片進行測試

# %% [markdown]
# ## 🚀 步驟四：口試專題的Streamlit Cloud 「防睡眠」實戰策略
#
#
# 為避免口試評審教授手機或電腦，點開專題時，看到「Zzzz 睡著畫面」或卡住，可以這樣做：
#  1. 口試前 10 分鐘自主喚醒
#  2. GitHub 儲存庫有新的 Commit（提交）
#  3. 進階防睡（加分嘗試）：部分學生會利用 GitHub Actions 設定定時任務（Cron Job）
